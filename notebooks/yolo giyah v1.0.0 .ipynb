# %% [markdown]
# 👋 1. نصب کتابخانه‌های مورد نیاز
# 1. Install the required libraries

# %%
# !pip install ultralytics roboflow --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 54.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...

# %% [markdown]
#  👇 2. وارد کردن کلید API Roboflow
#
#    Enter Roboflow API key

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="x7xYCsSe53W3aOZ1lP4h")
project = rf.workspace("drone-kfge0").project("saffron-i7fdm")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to saffron-2 in yolov8:: 100%|██████████| 6470/6470 [00:01<00:00, 5621.89it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# 📁 مسیر دیتاست برای YOLO
#
# 📁 Dataset path for YOLO

# %%
dataset_location = dataset.location  # مثلاً "/content/Dataset-1"

# %% [markdown]
# 👀 نمایش مسیر دانلود‌شده
#
# 👀 Show downloaded path

# %%
print("Dataset downloaded to:", dataset_location)
# Out:
# Dataset downloaded to: /content/saffron-2

# %% [markdown]
#  🧠 3. آموزش مدل YOLOv8
#
#  🧠 3. Training the YOLOv8 model

# %%
from ultralytics import YOLO

# %% [markdown]
#  بارگذاری مدل پایه YOLOv8n (مناسب برای آموزش اولیه و سبک)
#
#  Load the base YOLOv8n model (suitable for basic and light training)

# %%
model = YOLO("yolov8m.pt")

# %% [markdown]
#  شروع آموزش مدل
#
#  Start training the model

# %%
model.train(
    data=f"{dataset_location}/data.yaml",
    epochs=100,
    imgsz=1024,
    batch=8,
    name="yolov8n-medicinal-plants",
)
# Out:
# Ultralytics 8.3.177 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# اجازه دسترسی کولب به گوگل درایو
#
# Allow colab access to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# انتقال به گوگل **درایو**
#
# Transfer to Google **Drive**

# %%
# !cp -r /content/saffron-2 /content/drive/MyDrive/
